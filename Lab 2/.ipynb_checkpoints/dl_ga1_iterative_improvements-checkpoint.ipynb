# %% [markdown]
# # Analysis of the provided model

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)

# helper libraries
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import pandas as pd

# fix random seed for reproducibility
seed = 2020
np.random.seed(seed)  

import sklearn as sk
from sklearn.model_selection import train_test_split

from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
# Out:
# 1.14.0

# %%
# helper functions for visualisation
def plot_history(history):
  plt.figure(figsize = (12,4))
  plt.subplot(1,2,1)

  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.plot(history.epoch, np.array(history.history['accuracy']),'g-',
           label='Train accuracy')
  plt.plot(history.epoch, np.array(history.history['val_accuracy']),'r-',
           label = 'Validation accuracy')
  plt.legend()

  plt.subplot(1,2,2)
  plt.xlabel('Epoch')
  plt.ylabel('Loss minimised by model')
  plt.plot(history.epoch, np.array(history.history['loss']),'g-',
           label='Train loss')
  plt.plot(history.epoch, np.array(history.history['val_loss']),'r-',
           label = 'Validation loss')
  plt.legend()

# %%
try:
    from google.colab import drive
    drive.mount('/content/gdrive')

    import os

    #!ls '/content/gdrive/My Drive/'
except Exception:
    pass
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# load train and test data
(x_train_all, r_train_all_class), (x_test, r_test_class) = mnist.load_data()
x_train_all = x_train_all.reshape(x_train_all.shape[0], -1)
x_test = x_test.reshape(x_test.shape[0], -1)

# some preprocessing ... convert integers to floating point and rescale them to [0,1] range
x_train_all = x_train_all.astype('float32')
x_test = x_test.astype('float32')
x_train_all /= 255
x_test /= 255

# number of test samples
N_test = x_test.shape[0]

# split off 10000 samples for validation
N_val = 10000
N_train = x_train_all.shape[0] - N_val

# now extract the samples into train, validate and test sets
# set random state to make sure you get the same split each time
x_train, x_val, r_train_class, r_val_class = train_test_split(x_train_all, r_train_all_class, test_size = N_val, random_state=0)

r_train_all = tf.keras.utils.to_categorical(r_train_all_class)
r_train = tf.keras.utils.to_categorical(r_train_class)
r_val = tf.keras.utils.to_categorical(r_val_class)
r_test = tf.keras.utils.to_categorical(r_test_class)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step

# %%
num_classes = 10

def initial_model(lr=0.001):
    model = Sequential()
    model.add(Dense(16, activation='relu', input_shape=(784,), kernel_initializer='he_uniform'))
    model.add(Dense(16, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(lr=lr),
                  metrics=['accuracy'])

    return model

# %%
checkpoint_dir = "/content/gdrive/My Drive/Colab Notebooks/DL2020/GA1/"
model_savename = checkpoint_dir+"model_model_version_0.1.h5"
checkpoint_path = checkpoint_dir+"cp-{epoch:04d}.ckpt"

# create your model
model = initial_model(lr=0.001)
model.summary()

batch_size = 16
epochs = 20

# modelcheckpoint callback:
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, 
                                                 monitor='val_accuracy',
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 verbose=1)

history = model.fit(x_train, r_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks = [cp_callback],
                    validation_data=(x_val, r_val))
# Out:
# WARNING:tensorflow:From C:\Users\Gebruiker\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                12560
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 13,002
# Trainable params: 13,002
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 49744/50000 [============================>.] - ETA: 0s - loss: 0.4103 - acc: 0.8801- ETA: 1s WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 50000/50000 [==============================] - 8s 155us/sample - loss: 0.4095 - acc: 0.8803 - val_loss: 0.2354 - val_acc: 0.9317
# Epoch 2/20
# 49936/50000 [============================>.] - ETA: 0s - loss: 0.2217 - acc: 0.9356WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 50000/50000 [==============================] - 7s 141us/sample - loss: 0.2215 - acc: 0.9356 - val_loss: 0.1924 - val_acc: 0.9409
# Epoch 3/20
# 49856/50000 [============================>.] - ETA: 0s - loss: 0.1866 - acc: 0.9459WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 50000/50000 [==============================] - 8s 156us/sample - loss: 0.1868 - acc: 0.9458 - val_loss: 0.1745 - val_acc: 0.9478
# Epoch 4/20
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1662 - acc: 0.9517WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 50000/50000 [==============================] - 7s 142us/sample - loss: 0.1663 - acc: 0.9517 - val_loss: 0.1787 - val_acc: 0.9420
# Epoch 5/20
# 49904/50000 [============================>.] - ETA: 0s - loss: 0.1540 - acc: 0.9548WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 50000/50000 [==============================] - 7s 148us/sample - loss: 0.1540 - acc: 0.9548 - val_loss: 0.1571 - val_acc: 0.9506
# Epoch 6/20
# 49760/50000 [============================>.] - ETA: 0s - loss: 0.1437 - acc: 0.9570WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 50000/50000 [==============================] - 6s 129us/sample - loss: 0.1438 - acc: 0.9569 - val_loss: 0.1612 - val_acc: 0.9521
# Epoch 7/20
# 49504/50000 [============================>.] - ETA: 0s - loss: 0.1335 - acc: 0.9596WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 50000/50000 [==============================] - 6s 113us/sample - loss: 0.1337 - acc: 0.9595 - val_loss: 0.1559 - val_acc: 0.9539
# Epoch 8/20
# 49888/50000 [============================>.] - ETA: 0s - loss: 0.1273 - acc: 0.9620WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 50000/50000 [==============================] - 6s 127us/sample - loss: 0.1274 - acc: 0.9620 - val_loss: 0.1584 - val_acc: 0.9504
# Epoch 9/20
# 49280/50000 [============================>.] - ETA: 0s - loss: 0.1214 - acc: 0.9636

# %%
[train_loss, train_accuracy] = model.evaluate(x_train, r_train, verbose=0)
print("Training set Accuracy:{:7.2f}".format(train_accuracy))
print("Training set Loss:{:7.4f}\n".format(train_loss))

[val_loss, val_accuracy] = model.evaluate(x_val, r_val, verbose=0)
print("Validation set Accuracy:{:7.2f}".format(val_accuracy))
print("Validation set Loss:{:7.4f}\n".format(val_loss))

plot_history(history)
# Out:
# Training set Accuracy:   0.97
# Training set Loss: 0.0952
#
# Validation set Accuracy:   0.95
# Validation set Loss: 0.1712

# %%
model = initial_model(lr=0.001)
model.summary()

history = model.fit(x_train_all, r_train_all,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks = [cp_callback])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 16)                12560
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                170
# =================================================================
# Total params: 13,002
# Trainable params: 13,002
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.3667 - accuracy: 0.8918
# Epoch 2/20
# 60000/60000 [==============================] - 8s 129us/sample - loss: 0.2127 - accuracy: 0.9378
# Epoch 3/20
# 60000/60000 [==============================] - 8s 130us/sample - loss: 0.1809 - accuracy: 0.9466
# Epoch 4/20
# 60000/60000 [==============================] - 8s 130us/sample - loss: 0.1623 - accuracy: 0.9513
# Epoch 5/20
# 60000/60000 [==============================] - 8s 134us/sample - loss: 0.1488 - accuracy: 0.9554
# Epoch 6/20
# 60000/60000 [==============================] - 8s 136us/sample - loss: 0.1409 - accuracy: 0.9578
# Epoch 7/20
# 60000/60000 [==============================] - 8s 132us/sample - loss: 0.1350 - accuracy: 0.9596
# Epoch 8/20
# 60000/60000 [==============================] - 8s 131us/sample - loss: 0.1275 - accuracy: 0.9615
# Epoch 9/20
# 60000/60000 [==============================] - 8s 131us/sample - loss: 0.1228 - accuracy: 0.9617
# Epoch 10/20
# 60000/60000 [==============================] - 8s 129us/sample - loss: 0.1192 - accuracy: 0.9627
# Epoch 11/20
# 60000/60000 [==============================] - 8s 127us/sample - loss: 0.1156 - accuracy: 0.9644
# Epoch 12/20
# 60000/60000 [==============================] - 8s 126us/sample - loss: 0.1133 - accuracy: 0.9653
# Epoch 13/20
# 60000/60000 [==============================] - 8s 132us/sample - loss: 0.1091 - accuracy: 0.9659
# Epoch 14/20
# 60000/60000 [==============================] - 8s 130us/sample - loss: 0.1062 - accuracy: 0.9682
# Epoch 15/20
# 60000/60000 [==============================] - 8s 129us/sample - loss: 0.1039 - accuracy: 0.9673
# Epoch 16/20
# 60000/60000 [==============================] - 8s 126us/sample - loss: 0.1020 - accuracy: 0.9685
# Epoch 17/20
# 60000/60000 [==============================] - 8s 130us/sample - loss: 0.0992 - accuracy: 0.9693
# Epoch 18/20
# 60000/60000 [==============================] - 8s 134us/sample - loss: 0.0980 - accuracy: 0.9693
# Epoch 19/20
# 60000/60000 [==============================] - 8s 127us/sample - loss: 0.0953 - accuracy: 0.9698
# Epoch 20/20
# 60000/60000 [==============================] - 8s 130us/sample - loss: 0.0948 - accuracy: 0.9703

# %%
plt.figure(figsize = (12,4))
plt.subplot(1,2,1)

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(history.epoch, np.array(history.history['accuracy']),'g-',
        label='Train accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.xlabel('Epoch')
plt.ylabel('Loss minimised by model')
plt.plot(history.epoch, np.array(history.history['loss']),'g-',
        label='Train loss')
plt.legend()

# %%
# the file type for storing complete models is ".h5"
# feel free to change the path to whatever suits you best!
modelpath = checkpoint_dir+"final_model.h5"

print("Final model saved as ",modelpath)

# Save entire model to a HDF5 file
model.save(modelpath)
# Out:
# Final model saved as  /content/gdrive/My Drive/Colab Notebooks/DL2020/GA1/final_model.h5

# %%
# The code below should give the same results as that for the original model
[train_loss, train_accuracy] = model.evaluate(x_train_all, r_train_all, verbose=0)
print("Training set Accuracy:{:7.2f}".format(train_accuracy))
print("Training set Loss:{:7.4f}\n".format(train_loss))

[val_loss, val_accuracy] = model.evaluate(x_test, r_test, verbose=0)
print("Test set Accuracy:{:7.2f}".format(val_accuracy))
print("Test set Loss:{:7.4f}\n".format(val_loss))
# Out:
# Training set Accuracy:   0.97
# Training set Loss: 0.0858
#
# Test set Accuracy:   0.96
# Test set Loss: 0.1638

# %% [markdown]
# # Making the model powerful enough

# %% [markdown]
# Define a new model with more layers and more nodes in its layers.

# %%
def new_model(lr=0.001):
    model = Sequential()
    model.add(Dense(128, activation='relu', input_shape=(784,), kernel_initializer='he_uniform'))
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(64, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(64, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(32, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(lr=lr),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# Make the batch size as high as possible (None means that the whole training set will be used as a single batch, so batch gradient descent instead of minibatch gradient descent).

# %%
model = new_model(lr=0.0001)
model.summary()

batch_size = None
epochs = 50

history = model.fit(x_train, r_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks = [cp_callback],
                    validation_data=(x_val, r_val))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_20 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_21 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                330
# =================================================================
# Total params: 131,818
# Trainable params: 131,818
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 8s 152us/sample - loss: 0.6076 - accuracy: 0.8241 - val_loss: 0.2446 - val_accuracy: 0.9268
# Epoch 2/50
# 50000/50000 [==============================] - 8s 159us/sample - loss: 0.2164 - accuracy: 0.9367 - val_loss: 0.1662 - val_accuracy: 0.9521
# Epoch 3/50
# 50000/50000 [==============================] - 7s 145us/sample - loss: 0.1613 - accuracy: 0.9541 - val_loss: 0.1414 - val_accuracy: 0.9574
# Epoch 4/50
# 50000/50000 [==============================] - 7s 137us/sample - loss: 0.1295 - accuracy: 0.9624 - val_loss: 0.1210 - val_accuracy: 0.9635
# Epoch 5/50
# 50000/50000 [==============================] - 7s 141us/sample - loss: 0.1071 - accuracy: 0.9687 - val_loss: 0.1147 - val_accuracy: 0.9640
# Epoch 6/50
# 50000/50000 [==============================] - 7s 142us/sample - loss: 0.0904 - accuracy: 0.9739 - val_loss: 0.0985 - val_accuracy: 0.9686
# Epoch 7/50
# 50000/50000 [==============================] - 7s 139us/sample - loss: 0.0764 - accuracy: 0.9777 - val_loss: 0.0987 - val_accuracy: 0.9686
# Epoch 8/50
# 50000/50000 [==============================] - 7s 147us/sample - loss: 0.0660 - accuracy: 0.9811 - val_loss: 0.0935 - val_accuracy: 0.9694
# Epoch 9/50
# 50000/50000 [==============================] - 7s 143us/sample - loss: 0.0564 - accuracy: 0.9837 - val_loss: 0.0911 - val_accuracy: 0.9712
# Epoch 10/50
# 50000/50000 [==============================] - 7s 131us/sample - loss: 0.0488 - accuracy: 0.9863 - val_loss: 0.0865 - val_accuracy: 0.9709
# Epoch 11/50
# 50000/50000 [==============================] - 7s 148us/sample - loss: 0.0422 - accuracy: 0.9880 - val_loss: 0.0912 - val_accuracy: 0.9721
# Epoch 12/50
# 50000/50000 [==============================] - 7s 138us/sample - loss: 0.0362 - accuracy: 0.9894 - val_loss: 0.0839 - val_accuracy: 0.9740
# Epoch 13/50
# 50000/50000 [==============================] - 7s 138us/sample - loss: 0.0313 - accuracy: 0.9917 - val_loss: 0.0820 - val_accuracy: 0.9750
# Epoch 14/50
# 50000/50000 [==============================] - 7s 142us/sample - loss: 0.0278 - accuracy: 0.9921 - val_loss: 0.0837 - val_accuracy: 0.9754
# Epoch 15/50
# 50000/50000 [==============================] - 7s 140us/sample - loss: 0.0240 - accuracy: 0.9937 - val_loss: 0.0905 - val_accuracy: 0.9740
# Epoch 16/50
# 50000/50000 [==============================] - 7s 139us/sample - loss: 0.0204 - accuracy: 0.9945 - val_loss: 0.0899 - val_accuracy: 0.9734
# Epoch 17/50
# 50000/50000 [==============================] - 7s 138us/sample - loss: 0.0175 - accuracy: 0.9954 - val_loss: 0.0916 - val_accuracy: 0.9739
# Epoch 18/50
# 50000/50000 [==============================] - 7s 140us/sample - loss: 0.0151 - accuracy: 0.9959 - val_loss: 0.1027 - val_accuracy: 0.9725
# Epoch 19/50
# 50000/50000 [==============================] - 7s 143us/sample - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.0915 - val_accuracy: 0.9756
# Epoch 20/50
# 50000/50000 [==============================] - 7s 147us/sample - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.1033 - val_accuracy: 0.9719
# Epoch 21/50
# 50000/50000 [==============================] - 7s 149us/sample - loss: 0.0100 - accuracy: 0.9978 - val_loss: 0.0953 - val_accuracy: 0.9758
# Epoch 22/50
# 50000/50000 [==============================] - 8s 151us/sample - loss: 0.0093 - accuracy: 0.9976 - val_loss: 0.0956 - val_accuracy: 0.9758
# Epoch 23/50
# 50000/50000 [==============================] - 7s 149us/sample - loss: 0.0073 - accuracy: 0.9984 - val_loss: 0.1050 - val_accuracy: 0.9743
# Epoch 24/50
# 50000/50000 [==============================] - 7s 138us/sample - loss: 0.0076 - accuracy: 0.9982 - val_loss: 0.0984 - val_accuracy: 0.9767
# Epoch 25/50
# 50000/50000 [==============================] - 7s 137us/sample - loss: 0.0063 - accuracy: 0.9986 - val_loss: 0.0969 - val_accuracy: 0.9765
# Epoch 26/50
# 50000/50000 [==============================] - 6s 128us/sample - loss: 0.0061 - accuracy: 0.9986 - val_loss: 0.1053 - val_accuracy: 0.9763
# Epoch 27/50
# 50000/50000 [==============================] - 7s 141us/sample - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.1049 - val_accuracy: 0.9761
# Epoch 28/50
# 50000/50000 [==============================] - 7s 144us/sample - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.1164 - val_accuracy: 0.9753
# Epoch 29/50
# 50000/50000 [==============================] - 7s 143us/sample - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.1188 - val_accuracy: 0.9742
# Epoch 30/50
# 50000/50000 [==============================] - 7s 139us/sample - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.1180 - val_accuracy: 0.9747
# Epoch 31/50
# 50000/50000 [==============================] - 7s 140us/sample - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.1080 - val_accuracy: 0.9772
# Epoch 32/50
# 50000/50000 [==============================] - 7s 138us/sample - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.1212 - val_accuracy: 0.9739
# Epoch 33/50
# 50000/50000 [==============================] - 7s 137us/sample - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.1112 - val_accuracy: 0.9762
# Epoch 34/50
# 50000/50000 [==============================] - 7s 139us/sample - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.1179 - val_accuracy: 0.9763
# Epoch 35/50
# 50000/50000 [==============================] - 6s 128us/sample - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.1147 - val_accuracy: 0.9785
# Epoch 36/50
# 50000/50000 [==============================] - 7s 143us/sample - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.1273 - val_accuracy: 0.9739
# Epoch 37/50
# 50000/50000 [==============================] - 7s 143us/sample - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.1164 - val_accuracy: 0.9765
# Epoch 38/50
# 50000/50000 [==============================] - 7s 135us/sample - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.1200 - val_accuracy: 0.9756
# Epoch 39/50
# 50000/50000 [==============================] - 7s 145us/sample - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1265 - val_accuracy: 0.9761
# Epoch 40/50
# 50000/50000 [==============================] - 7s 143us/sample - loss: 4.7012e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9772
# Epoch 41/50
# 50000/50000 [==============================] - 8s 152us/sample - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.1246 - val_accuracy: 0.9756
# Epoch 42/50
# 50000/50000 [==============================] - 8s 157us/sample - loss: 7.1731e-04 - accuracy: 0.9999 - val_loss: 0.1306 - val_accuracy: 0.9763
# Epoch 43/50
# 50000/50000 [==============================] - 7s 137us/sample - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.1236 - val_accuracy: 0.9763
# Epoch 44/50
# 50000/50000 [==============================] - 7s 139us/sample - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.1178 - val_accuracy: 0.9769
# Epoch 45/50
# 50000/50000 [==============================] - 8s 157us/sample - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.1221 - val_accuracy: 0.9759
# Epoch 46/50
# 50000/50000 [==============================] - 7s 147us/sample - loss: 6.4354e-04 - accuracy: 0.9999 - val_loss: 0.1168 - val_accuracy: 0.9777
# Epoch 47/50
# 50000/50000 [==============================] - 7s 133us/sample - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.1353 - val_accuracy: 0.9762
# Epoch 48/50
# 50000/50000 [==============================] - 7s 141us/sample - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.1161 - val_accuracy: 0.9784
# Epoch 49/50
# 50000/50000 [==============================] - 7s 145us/sample - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.1201 - val_accuracy: 0.9768
# Epoch 50/50
# 50000/50000 [==============================] - 7s 140us/sample - loss: 3.6258e-04 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.9775

# %%
[train_loss, train_accuracy] = model.evaluate(x_train, r_train, verbose=0)
print("Training set Accuracy:{:7.2f}".format(train_accuracy))
print("Training set Loss:{:7.4f}\n".format(train_loss))

[val_loss, val_accuracy] = model.evaluate(x_val, r_val, verbose=0)
print("Validation set Accuracy:{:7.2f}".format(val_accuracy))
print("Validation set Loss:{:7.4f}\n".format(val_loss))

plot_history(history)
# Out:
# Training set Accuracy:   1.00
# Training set Loss: 0.0003
#
# Validation set Accuracy:   0.98
# Validation set Loss: 0.1201

# %%
model = new_model(lr=0.0001)
model.summary()

history = model.fit(x_train_all, r_train_all,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks = [cp_callback])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_31 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_32 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_34 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_35 (Dense)             (None, 10)                330
# =================================================================
# Total params: 131,818
# Trainable params: 131,818
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.5598 - accuracy: 0.8339
# Epoch 2/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 0.1845 - accuracy: 0.9454
# Epoch 3/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 0.1346 - accuracy: 0.9597
# Epoch 4/50
# 60000/60000 [==============================] - 8s 127us/sample - loss: 0.1083 - accuracy: 0.9679
# Epoch 5/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 0.0900 - accuracy: 0.9738
# Epoch 6/50
# 60000/60000 [==============================] - 7s 122us/sample - loss: 0.0767 - accuracy: 0.9772
# Epoch 7/50
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.0663 - accuracy: 0.9799
# Epoch 8/50
# 60000/60000 [==============================] - 8s 130us/sample - loss: 0.0578 - accuracy: 0.9828
# Epoch 9/50
# 60000/60000 [==============================] - 8s 129us/sample - loss: 0.0500 - accuracy: 0.9855
# Epoch 10/50
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.0443 - accuracy: 0.9867
# Epoch 11/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 0.0390 - accuracy: 0.9885
# Epoch 12/50
# 60000/60000 [==============================] - 8s 125us/sample - loss: 0.0333 - accuracy: 0.9905
# Epoch 13/50
# 60000/60000 [==============================] - 7s 122us/sample - loss: 0.0296 - accuracy: 0.9918
# Epoch 14/50
# 60000/60000 [==============================] - 7s 120us/sample - loss: 0.0255 - accuracy: 0.9927
# Epoch 15/50
# 60000/60000 [==============================] - 8s 129us/sample - loss: 0.0231 - accuracy: 0.9936
# Epoch 16/50
# 60000/60000 [==============================] - 8s 127us/sample - loss: 0.0192 - accuracy: 0.9950
# Epoch 17/50
# 60000/60000 [==============================] - 8s 130us/sample - loss: 0.0174 - accuracy: 0.9952
# Epoch 18/50
# 60000/60000 [==============================] - 7s 124us/sample - loss: 0.0150 - accuracy: 0.9960
# Epoch 19/50
# 60000/60000 [==============================] - 7s 121us/sample - loss: 0.0126 - accuracy: 0.9969
# Epoch 20/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 0.0124 - accuracy: 0.9966
# Epoch 21/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 0.0106 - accuracy: 0.9971
# Epoch 22/50
# 60000/60000 [==============================] - 7s 121us/sample - loss: 0.0089 - accuracy: 0.9978
# Epoch 23/50
# 60000/60000 [==============================] - 8s 127us/sample - loss: 0.0077 - accuracy: 0.9980
# Epoch 24/50
# 60000/60000 [==============================] - 8s 130us/sample - loss: 0.0071 - accuracy: 0.9980
# Epoch 25/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 0.0062 - accuracy: 0.9985
# Epoch 26/50
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.0053 - accuracy: 0.9987
# Epoch 27/50
# 60000/60000 [==============================] - 9s 145us/sample - loss: 0.0060 - accuracy: 0.9982
# Epoch 28/50
# 60000/60000 [==============================] - 8s 128us/sample - loss: 0.0050 - accuracy: 0.9986
# Epoch 29/50
# 60000/60000 [==============================] - 7s 122us/sample - loss: 0.0044 - accuracy: 0.9987
# Epoch 30/50
# 60000/60000 [==============================] - 7s 122us/sample - loss: 0.0041 - accuracy: 0.9989
# Epoch 31/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 0.0051 - accuracy: 0.9988
# Epoch 32/50
# 60000/60000 [==============================] - 8s 129us/sample - loss: 0.0040 - accuracy: 0.9990
# Epoch 33/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 0.0034 - accuracy: 0.9990
# Epoch 34/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 0.0060 - accuracy: 0.9983
# Epoch 35/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 0.0030 - accuracy: 0.9990
# Epoch 36/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 0.0038 - accuracy: 0.9989
# Epoch 37/50
# 60000/60000 [==============================] - 8s 125us/sample - loss: 0.0029 - accuracy: 0.9992
# Epoch 38/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 0.0019 - accuracy: 0.9997
# Epoch 39/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 0.0041 - accuracy: 0.9989
# Epoch 40/50
# 60000/60000 [==============================] - 8s 128us/sample - loss: 0.0035 - accuracy: 0.9990
# Epoch 41/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 0.0041 - accuracy: 0.9987
# Epoch 42/50
# 60000/60000 [==============================] - 8s 125us/sample - loss: 0.0018 - accuracy: 0.9994
# Epoch 43/50
# 60000/60000 [==============================] - 8s 130us/sample - loss: 0.0039 - accuracy: 0.9990
# Epoch 44/50
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.0029 - accuracy: 0.9991
# Epoch 45/50
# 60000/60000 [==============================] - 10s 169us/sample - loss: 0.0029 - accuracy: 0.9992
# Epoch 46/50
# 60000/60000 [==============================] - 8s 138us/sample - loss: 0.0028 - accuracy: 0.9992
# Epoch 47/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 3.0658e-04 - accuracy: 1.0000
# Epoch 48/50
# 60000/60000 [==============================] - 8s 128us/sample - loss: 0.0053 - accuracy: 0.9983
# Epoch 49/50
# 60000/60000 [==============================] - 8s 129us/sample - loss: 0.0013 - accuracy: 0.9997
# Epoch 50/50
# 60000/60000 [==============================] - 7s 124us/sample - loss: 1.7466e-04 - accuracy: 1.0000

# %%
plt.figure(figsize = (12,4))
plt.subplot(1,2,1)

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(history.epoch, np.array(history.history['accuracy']),'g-',
        label='Train accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.xlabel('Epoch')
plt.ylabel('Loss minimised by model')
plt.plot(history.epoch, np.array(history.history['loss']),'g-',
        label='Train loss')
plt.legend()

# %%
# the file type for storing complete models is ".h5"
# feel free to change the path to whatever suits you best!
modelpath = checkpoint_dir+"final_model.h5"

print("Final model saved as ",modelpath)

# Save entire model to a HDF5 file
model.save(modelpath)
# Out:
# Final model saved as  /content/gdrive/My Drive/Colab Notebooks/DL2020/GA1/final_model.h5

# %%
[train_loss, train_accuracy] = model.evaluate(x_train_all, r_train_all, verbose=0)
print("Training set Accuracy:{:7.2f}".format(train_accuracy))
print("Training set Loss:{:7.4f}\n".format(train_loss))

[val_loss, val_accuracy] = model.evaluate(x_test, r_test, verbose=0)
print("Test set Accuracy:{:7.2f}".format(val_accuracy))
print("Test set Loss:{:7.4f}\n".format(val_loss))
# Out:
# Training set Accuracy:   1.00
# Training set Loss: 0.0001
#
# Test set Accuracy:   0.98
# Test set Loss: 0.1305

# %% [markdown]
# # Regularizing

# %% [markdown]
# Create a regularized version of the previous model: L1/2 regularization, early stopping and dropout.

# %%
def regularized_model(lr=0.001, regularizer=tf.keras.regularizers.l2()):
    model = Sequential()
    # model.add(Dropout)
    model.add(Dense(128, activation='relu', input_shape=(784,), kernel_initializer='he_uniform', kernel_regularizer=regularizer, bias_regularizer=regularizer))
    # model.add(Dropout)
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizer, bias_regularizer=regularizer))
    # model.add(Dropout)
    model.add(Dense(64, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizer, bias_regularizer=regularizer))
    # model.add(Dropout)
    model.add(Dense(64, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizer, bias_regularizer=regularizer))
    # model.add(Dropout)
    model.add(Dense(32, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizer, bias_regularizer=regularizer))
    # model.add(Dropout)
    model.add(Dense(num_classes, activation='softmax', kernel_regularizer=regularizer, bias_regularizer=regularizer))

    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(lr=lr),
                  metrics=['accuracy'])
    return model

# %%
# regularizer = None
# regularizer = tf.keras.regularizers.l1()
regularizer = tf.keras.regularizers.l2()

model = regularized_model(lr=0.0001, regularizer=regularizer)
model.summary()

batch_size = None
epochs = 50

# early stopping
es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, min_delta=0.0001)

history = model.fit(x_train, r_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks = [cp_callback, ses_callback],
                    validation_data=(x_val, r_val))
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_39 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_40 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_41 (Dense)             (None, 10)                330
# =================================================================
# Total params: 131,818
# Trainable params: 131,818
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 9s 179us/sample - loss: 5.3864 - accuracy: 0.7905 - val_loss: 3.2404 - val_accuracy: 0.9085
# Epoch 2/50
# 50000/50000 [==============================] - 8s 158us/sample - loss: 2.5876 - accuracy: 0.9111 - val_loss: 2.1081 - val_accuracy: 0.9209
# Epoch 3/50
# 50000/50000 [==============================] - 8s 159us/sample - loss: 1.8686 - accuracy: 0.9187 - val_loss: 1.6504 - val_accuracy: 0.9260
# Epoch 4/50
# 50000/50000 [==============================] - 8s 160us/sample - loss: 1.5328 - accuracy: 0.9244 - val_loss: 1.4032 - val_accuracy: 0.9304
# Epoch 5/50
# 50000/50000 [==============================] - 8s 158us/sample - loss:
# Epoch 28/50
# 50000/50000 [==============================] - 8s 160us/sample - loss: 0.8667 - accuracy: 0.9459 - val_loss: 0.8577 - val_accuracy: 0.9493
# Epoch 29/50
# 50000/50000 [==============================] - 8s 169us/sample - loss: 0.8654 - accuracy: 0.9461 - val_loss: 0.8562 - val_accuracy: 0.9506
# Epoch 30/50
# 50000/50000 [==============================] - 8s 162us/sample - loss: 0.8646 - accuracy: 0.9465 - val_loss: 0.8543 - val_accuracy: 0.9499
# Epoch 31/50
# 50000/50000 [==============================] - 8s 164us/sample - loss: 0.8639 - accuracy: 0.9457 - val_loss: 0.8576 - val_accuracy: 0.9492
# Epoch 32/50
# 50000/50000 [==============================] - 8s 164us/sample - loss: 0.8634 - accuracy: 0.9462 - val_loss: 0.8555 - val_accuracy: 0.9492
# Epoch 33/50
# 50000/50000 [==============================] - 8s 169us/sample - loss: 0.8627 - accuracy: 0.9473 - val_loss: 0.8514 - val_accuracy: 0.9506
# Epoch 34/50
# 50000/50000 [==============================] - 8s 170us/sample - loss: 0.8613 - accuracy: 0.9466 - val_loss: 0.8512 - val_accuracy: 0.9524
# Epoch 35/50
# 50000/50000 [==============================] - 8s 165us/sample - loss: 0.8615 - accuracy: 0.9472 - val_loss: 0.8543 - val_accuracy: 0.9520
# Epoch 36/50
# 50000/50000 [==============================] - 8s 165us/sample - loss: 0.8610 - accuracy: 0.9474 - val_loss: 0.8516 - val_accuracy: 0.9514
# Epoch 37/50
# 50000/50000 [==============================] - 8s 166us/sample - loss: 0.8604 - accuracy: 0.9479 - val_loss: 0.8540 - val_accuracy: 0.9494
# Epoch 38/50
# 50000/50000 [==============================] - 8s 156us/sample - loss: 0.8596 - accuracy: 0.9479 - val_loss: 0.8526 - val_accuracy: 0.9527
# Epoch 39/50
# 50000/50000 [==============================] - 8s 160us/sample - loss: 0.8595 - accuracy: 0.9479 - val_loss: 0.8526 - val_accuracy: 0.9511
# Epoch 40/50
# 50000/50000 [==============================] - 8s 164us/sample - loss: 0.8594 - accuracy: 0.9473 - val_loss: 0.8497 - val_accuracy: 0.9517
# Epoch 41/50
# 50000/50000 [==============================] - 8s 165us/sample - loss: 0.8588 - accuracy: 0.9472 - val_loss: 0.8487 - val_accuracy: 0.9518
# Epoch 42/50
# 50000/50000 [==============================] - 8s 160us/sample - loss: 0.8580 - accuracy: 0.9476 - val_loss: 0.8517 - val_accuracy: 0.9512
# Epoch 43/50
# 50000/50000 [==============================] - 8s 159us/sample - loss: 0.8577 - accuracy: 0.9475 - val_loss: 0.8523 - val_accuracy: 0.9513
# Epoch 44/50
# 50000/50000 [==============================] - 8s 165us/sample - loss: 0.8574 - accuracy: 0.9475 - val_loss: 0.8500 - val_accuracy: 0.9507
# Epoch 45/50
# 50000/50000 [==============================] - 8s 159us/sample - loss: 0.8567 - accuracy: 0.9479 - val_loss: 0.8512 - val_accuracy: 0.9513
# Epoch 46/50
# 50000/50000 [==============================] - 8s 162us/sample - loss: 0.8569 - accuracy: 0.9474 - val_loss: 0.8485 - val_accuracy: 0.9515
# Epoch 47/50
# 50000/50000 [==============================] - 9s 180us/sample - loss: 0.8560 - accuracy: 0.9478 - val_loss: 0.8470 - val_accuracy: 0.9521
# Epoch 48/50
# 50000/50000 [==============================] - 8s 158us/sample - loss: 0.8557 - accuracy: 0.9492 - val_loss: 0.8478 - val_accuracy: 0.9505
# Epoch 49/50
# 50000/50000 [==============================] - 8s 152us/sample - loss: 0.8557 - accuracy: 0.9474 - val_loss: 0.8489 - val_accuracy: 0.9507
# Epoch 50/50
# 50000/50000 [==============================] - 8s 167us/sample - loss: 0.8555 - accuracy: 0.9480 - val_loss: 0.8501 - val_accuracy: 0.9501

# %%
[train_loss, train_accuracy] = model.evaluate(x_train, r_train, verbose=0)
print("Training set Accuracy:{:7.2f}".format(train_accuracy))
print("Training set Loss:{:7.4f}\n".format(train_loss))

[val_loss, val_accuracy] = model.evaluate(x_val, r_val, verbose=0)
print("Validation set Accuracy:{:7.2f}".format(val_accuracy))
print("Validation set Loss:{:7.4f}\n".format(val_loss))

plot_history(history)
# Out:
# Training set Accuracy:   0.95
# Training set Loss: 0.8503
#
# Validation set Accuracy:   0.95
# Validation set Loss: 0.8501

# %%
model = regularized_model(lr=0.0001, regularizer=regularizer)
model.summary()

history = model.fit(x_train_all, r_train_all,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks = [cp_callback])
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_43 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_44 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_45 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_46 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_47 (Dense)             (None, 10)                330
# =================================================================
# Total params: 131,818
# Trainable params: 131,818
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples
# Epoch 1/50
# 59744/60000 [============================>.] - ETA: 0s - loss: 5.0828 - accuracy: 0.8288WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 10s 162us/sample - loss: 5.0738 - accuracy: 0.8291
# Epoch 2/50
# 59936/60000 [============================>.] - ETA: 0s - loss: 2.3341 - accuracy: 0.9132WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 153us/sample - loss: 2.3337 - accuracy: 0.9131
# Epoch 3/50
# 59968/60000 [============================>.] - ETA: 0s - loss: 1.6881 - accuracy: 0.9192WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 148us/sample - loss: 1.6880 - accuracy: 0.9192
# Epoch 4/50
# 59776/60000 [============================>.] - ETA: 0s - loss: 1.4049 - accuracy: 0.9225WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 151us/sample - loss: 1.4044 - accuracy: 0.9226
# Epoch 5/50
# 59776/60000 [============================>.] - ETA: 0s - loss: 1.2452 - accuracy: 0.9256WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 146us/sample - loss: 1.2449 - accuracy: 0.9257
# Epoch 6/50
# 59872/60000 [============================>.] - ETA: 0s - loss: 1.1443 - accuracy: 0.9288WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 151us/sample - loss: 1.1442 - accuracy: 0.9288
# Epoch 7/50
# 59936/60000 [============================>.] - ETA: 0s - loss: 1.0767 - accuracy: 0.9311WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 152us/sample - loss: 1.0767 - accuracy: 0.9311
# Epoch 8/50
# 59680/60000 [============================>.] - ETA: 0s - loss: 1.0300 - accuracy: 0.9335WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 8s 138us/sample - loss: 1.0298 - accuracy: 0.9335
# Epoch 9/50
# 59968/60000 [============================>.] - ETA: 0s - loss: 0.9957 - accuracy: 0.9348WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 149us/sample - loss: 0.9957 - accuracy: 0.9348
# Epoch 10/50
# 59712/60000 [============================>.] - ETA: 0s - loss: 0.9698 - accuracy: 0.9365WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.9695 - accuracy: 0.9366
# Epoch 11/50
# 59744/60000 [============================>.] - ETA: 0s - loss: 0.9487 - accuracy: 0.9368WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 11s 175us/sample - loss: 0.9488 - accuracy: 0.9367
# Epoch 12/50
# 59680/60000 [============================>.] - ETA: 0s - loss: 0.9301 - accuracy: 0.9383WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 152us/sample - loss: 0.9300 - accuracy: 0.9384
# Epoch 13/50
# 59776/60000 [============================>.] - ETA: 0s - loss: 0.9147 - accuracy: 0.9395WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 147us/sample - loss: 0.9147 - accuracy: 0.9394
# Epoch 14/50
# 59968/60000 [============================>.] - ETA: 0s - loss: 0.9011 - accuracy: 0.9411WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.9011 - accuracy: 0.9410
# Epoch 15/50
# 59776/60000 [============================>.] - ETA: 0s - loss: 0.8924 - accuracy: 0.9411WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 10s 160us/sample - loss: 0.8922 - accuracy: 0.9413
# Epoch 16/50
# 59904/60000 [============================>.] - ETA: 0s - loss: 0.8830 - accuracy: 0.9426WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 148us/sample - loss: 0
ARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 156us/sample - loss: 0.8201 - accuracy: 0.9491
# Epoch 40/50
# 59808/60000 [============================>.] - ETA: 0s - loss: 0.8193 - accuracy: 0.9495WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.8193 - accuracy: 0.9495
# Epoch 41/50
# 59808/60000 [============================>.] - ETA: 0s - loss: 0.8191 - accuracy: 0.9492WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 149us/sample - loss: 0.8191 - accuracy: 0.9492
# Epoch 42/50
# 59936/60000 [============================>.] - ETA: 0s - loss: 0.8179 - accuracy: 0.9495WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 155us/sample - loss: 0.8181 - accuracy: 0.9495
# Epoch 43/50
# 59744/60000 [============================>.] - ETA: 0s - loss: 0.8178 - accuracy: 0.9494WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 147us/sample - loss: 0.8181 - accuracy: 0.9493
# Epoch 44/50
# 59744/60000 [============================>.] - ETA: 0s - loss: 0.8183 - accuracy: 0.9498WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 152us/sample - loss: 0.8181 - accuracy: 0.9498
# Epoch 45/50
# 59712/60000 [============================>.] - ETA: 0s - loss: 0.8173 - accuracy: 0.9504WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 146us/sample - loss: 0.8171 - accuracy: 0.9505
# Epoch 46/50
# 59840/60000 [============================>.] - ETA: 0s - loss: 0.8174 - accuracy: 0.9507WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 155us/sample - loss: 0.8176 - accuracy: 0.9506
# Epoch 47/50
# 59808/60000 [============================>.] - ETA: 0s - loss: 0.8163 - accuracy: 0.9505WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.8163 - accuracy: 0.9505
# Epoch 48/50
# 59776/60000 [============================>.] - ETA: 0s - loss: 0.8168 - accuracy: 0.9502WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 148us/sample - loss: 0.8167 - accuracy: 0.9503
# Epoch 49/50
# 59648/60000 [============================>.] - ETA: 0s - loss: 0.8165 - accuracy: 0.9499WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 144us/sample - loss: 0.8165 - accuracy: 0.9499
# Epoch 50/50
# 59776/60000 [============================>.] - ETA: 0s - loss: 0.8160 - accuracy: 0.9506WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 60000/60000 [==============================] - 9s 152us/sample - loss: 0.8161 - accuracy: 0.9505

# %%
[train_loss, train_accuracy] = model.evaluate(x_train_all, r_train_all, verbose=0)
print("Training set Accuracy:{:7.2f}".format(train_accuracy))
print("Training set Loss:{:7.4f}\n".format(train_loss))

[val_loss, val_accuracy] = model.evaluate(x_test, r_test, verbose=0)
print("Test set Accuracy:{:7.2f}".format(val_accuracy))
print("Test set Loss:{:7.4f}\n".format(val_loss))
# Out:
# Training set Accuracy:   0.95
# Training set Loss: 0.8128
#
# Test set Accuracy:   0.95
# Test set Loss: 0.8143

# %% [markdown]
# # Olivier

# %% [markdown]
# As mentioned in the training notebook, the model is overfitting to the training data. Therefore it is relevant to replot the validation curve.

# %% [markdown]
# The initial model will be retrained first.

# %%
# Out:
# 60000  original train samples
# 10000  original test samples
# Using  50000  train samples,  10000  validation samples and  10000  test samples
# Each sample has  784  features
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 8s 150us/sample - loss: 0.4330 - accuracy: 0.8735 - val_loss: 0.2551 - val_accuracy: 0.9265
# Epoch 2/10
# 50000/50000 [==============================] - 7s 140us/sample - loss: 0.2398 - accuracy: 0.9304 - val_loss: 0.2003 - val_accuracy: 0.9390
# Epoch 3/10
# 50000/50000 [==============================] - 7s 147us/sample - loss: 0.2020 - accuracy: 0.9409 - val_loss: 0.1876 - val_accuracy: 0.9401
# Epoch 4/10
# 50000/50000 [==============================] - 7s 140us/sample - loss: 0.1821 - accuracy: 0.9471 - val_loss: 0.1828 - val_accuracy: 0.9452
# Epoch 5/10
# 50000/50000 [==============================] - 7s 136us/sample - loss: 0.1662 - accuracy: 0.9502 - val_loss: 0.1638 - val_accuracy: 0.9481
# Epoch 6/10
# 50000/50000 [==============================] - 7s 145us/sample - loss: 0.1548 - accuracy: 0.9538 - val_loss: 0.1664 - val_accuracy: 0.9487
# Epoch 7/10
# 50000/50000 [==============================] - 7s 141us/sample - loss: 0.1466 - accuracy: 0.9565 - val_loss: 0.1541 - val_accuracy: 0.9526
# Epoch 8/10
# 50000/50000 [==============================] - 7s 146us/sample - loss: 0.1387 - accuracy: 0.9580 - val_loss: 0.1601 - val_accuracy: 0.9506
# Epoch 9/10
# 50000/50000 [==============================] - 7s 140us/sample - loss: 0.1322 - accuracy: 0.9602 - val_loss: 0.1644 - val_accuracy: 0.9511
# Epoch 10/10
# 50000/50000 [==============================] - 7s 143us/sample - loss: 0.1263 - accuracy: 0.9617 - val_loss: 0.1523 - val_accuracy: 0.9545

# %% [markdown]
# Now the training history can be plotted.

# %%
# Out:
# Training set Accuracy:   0.97
# Training set Loss: 0.1054
#
# Validation set Accuracy:   0.95
# Validation set Loss: 0.1523

# %% [markdown]
# Based on these validation curves, a first possible improvement would be to increase the batch size during training. A larger batch size increases the amount of samples during each training step, which results in a better estimate of the gradient and thus a more stable validation improvement.
# A batch size of 32, 64 and 128 will be tested during model training.

# %%
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 4s 88us/sample - loss: 0.4673 - accuracy: 0.8642 - val_loss: 0.2492 - val_accuracy: 0.9262
# Epoch 2/10
# 50000/50000 [==============================] - 4s 87us/sample - loss: 0.2397 - accuracy: 0.9321 - val_loss: 0.2031 - val_accuracy: 0.9403
# Epoch 3/10
# 50000/50000 [==============================] - 4s 88us/sample - loss: 0.2050 - accuracy: 0.9416 - val_loss: 0.1959 - val_accuracy: 0.9414
# Epoch 4/10
# 50000/50000 [==============================] - 4s 71us/sample - loss: 0.1822 - accuracy: 0.9480 - val_loss: 0.1834 - val_accuracy: 0.9450
# Epoch 5/10
# 50000/50000 [==============================] - 4s 79us/sample - loss: 0.1699 - accuracy: 0.9512 - val_loss: 0.1777 - val_accuracy: 0.9467
# Epoch 6/10
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.1576 - accuracy: 0.9539 - val_loss: 0.1716 - val_accuracy: 0.9474
# Epoch 7/10
# 50000/50000 [==============================] - 4s 78us/sample - loss: 0.1502 - accuracy: 0.9561 - val_loss: 0.1776 - val_accuracy: 0.9472
# Epoch 8/10
# 50000/50000 [==============================] - 4s 77us/sample - loss: 0.1426 - accuracy: 0.9589 - val_loss: 0.1584 - val_accuracy: 0.9539
# Epoch 9/10
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.1371 - accuracy: 0.9592 - val_loss: 0.1595 - val_accuracy: 0.9542
# Epoch 10/10
# 50000/50000 [==============================] - 4s 79us/sample - loss: 0.1309 - accuracy: 0.9607 - val_loss: 0.1594 - val_accuracy: 0.9543
# Training set Accuracy:   0.97
# Training set Loss: 0.1151
#
# Validation set Accuracy:   0.95
# Validation set Loss: 0.1594
#
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 3s 56us/sample - loss: 0.5967 - accuracy: 0.8261 - val_loss: 0.2797 - val_accuracy: 0.9211
# Epoch 2/10
# 50000/50000 [==============================] - 2s 45us/sample - loss: 0.2586 - accuracy: 0.9263 - val_loss: 0.2269 - val_accuracy: 0.9353
# Epoch 3/10
# 50000/50000 [==============================] - 2s 45us/sample - loss: 0.2147 - accuracy: 0.9383 - val_loss: 0.2059 - val_accuracy: 0.9415
# Epoch 4/10
# 50000/50000 [==============================] - 2s 46us/sample - loss: 0.1937 - accuracy: 0.9444 - val_loss: 0.1960 - val_accuracy: 0.9429
# Epoch 5/10
# 50000/50000 [==============================] - 2s 49us/sample - loss: 0.1790 - accuracy: 0.9481 - val_loss: 0.1862 - val_accuracy: 0.9461
# Epoch 6/10
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.1688 - accuracy: 0.9501 - val_loss: 0.1816 - val_accuracy: 0.9472
# Epoch 7/10
# 50000/50000 [==============================] - 2s 46us/sample - loss: 0.1593 - accuracy: 0.9530 - val_loss: 0.1777 - val_accuracy: 0.9495
# Epoch 8/10
# 50000/50000 [==============================] - 2s 50us/sample - loss: 0.1535 - accuracy: 0.9541 - val_loss: 0.1744 - val_accuracy: 0.9497
# Epoch 9/10
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.1465 - accuracy: 0.9570 - val_loss: 0.1766 - val_accuracy: 0.9489
# Epoch 10/10
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.1414 - accuracy: 0.9579 - val_loss: 0.1741 - val_accuracy: 0.9499
# Training set Accuracy:   0.96
# Training set Loss: 0.1296
#
# Validation set Accuracy:   0.95
# Validation set Loss: 0.1741
#
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 2s 39us/sample - loss: 0.7396 - accuracy: 0.7806 - val_loss: 0.3533 - val_accuracy: 0.8969
# Epoch 2/10
# 50000/50000 [==============================] - 1s 26us/sample - loss: 0.3155 - accuracy: 0.9090 - val_loss: 0.2777 - val_accuracy: 0.9177
# Epoch 3/10
# 50000/50000 [==============================] - 1s 29us/sample - loss: 0.2665 - accuracy: 0.9231 - val_loss: 0.2448 - val_accuracy: 0.9297
# Epoch 4/10
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.2384 - accuracy: 0.9323 - val_loss: 0.2277 - val_accuracy: 0.9313
# Epoch 5/10
# 50000/50000 [==============================] - 1s 27us/sample - loss: 0.2187 - accuracy: 0.9367 - val_loss: 0.2120 - val_accuracy: 0.9371
# Epoch 6/10
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.2046 - accuracy: 0.9410 - val_loss: 0.2088 - val_accuracy: 0.9383
# Epoch 7/10
# 50000/50000 [==============================] - 1s 26us/sample - loss: 0.1909 - accuracy: 0.9450 - val_loss: 0.2114 - val_accuracy: 0.9382
# Epoch 8/10
# 50000/50000 [==============================] - 1s 27us/sample - loss: 0.1831 - accuracy: 0.9462 - val_loss: 0.1958 - val_accuracy: 0.9414
# Epoch 9/10
# 50000/50000 [==============================] - 1s 30us/sample - loss: 0.1746 - accuracy: 0.9490 - val_loss: 0.1870 - val_accuracy: 0.9441
# Epoch 10/10
# 50000/50000 [==============================] - 2s 30us/sample - loss: 0.1681 - accuracy: 0.9501 - val_loss: 0.1819 - val_accuracy: 0.9439
# Training set Accuracy:   0.95
# Training set Loss: 0.1554
#
# Validation set Accuracy:   0.94
# Validation set Loss: 0.1819

# %% [markdown]
# There are no drastic improvements using these batch sizes.
# Another way to improve convergence is by lowering the learning rate.
# The default learning rate of the Adam optimizer is 0.001. Therefore learning rates of 0.0003 and 0.0001 will be tested during model training, while keeping the batch size at 64.

# %%
learning_rates = [0.0003,0.0001]
batch_size = 64
for lr in learning_rates:
  model = initial_model(lr=lr)
  model_history = model.fit(x_train, r_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val,r_val)
                    )
  analyse_result_plot(model,model_history)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 3s 55us/sample - loss: 0.9589 - accuracy: 0.7092 - val_loss: 0.3973 - val_accuracy: 0.8892
# Epoch 2/10
# 50000/50000 [==============================] - 2s 49us/sample - loss: 0.3534 - accuracy: 0.9001 - val_loss: 0.2989 - val_accuracy: 0.9154
# Epoch 3/10
# 50000/50000 [==============================] - 2s 46us/sample - loss: 0.2937 - accuracy: 0.9166 - val_loss: 0.2590 - val_accuracy: 0.9248
# Epoch 4/10
# 50000/50000 [==============================] - 2s 49us/sample - loss: 0.2629 - accuracy: 0.9252 - val_loss: 0.2402 - val_accuracy: 0.9302
# Epoch 5/10
# 50000/50000 [==============================] - 2s 49us/sample - loss: 0.2436 - accuracy: 0.9305 - val_loss: 0.2239 - val_accuracy: 0.9361
# Epoch 6/10
# 50000/50000 [==============================] - 2s 46us/sample - loss: 0.2288 - accuracy: 0.9342 - val_loss: 0.2139 - val_accuracy: 0.9383
# Epoch 7/10
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.2167 - accuracy: 0.9375 - val_loss: 0.2046 - val_accuracy: 0.9417
# Epoch 8/10
# 50000/50000 [==============================] - 2s 44us/sample - loss: 0.2073 - accuracy: 0.9395 - val_loss: 0.2015 - val_accuracy: 0.9424
# Epoch 9/10
# 50000/50000 [==============================] - 2s 47us/sample - loss: 0.1987 - accuracy: 0.9420 - val_loss: 0.1944 - val_accuracy: 0.9458
# Epoch 10/10
# 50000/50000 [==============================] - 2s 44us/sample - loss: 0.1923 - accuracy: 0.9440 - val_loss: 0.1893 - val_accuracy: 0.9460
# Training set Accuracy:   0.95
# Training set Loss: 0.1836
#
# Validation set Accuracy:   0.95
# Validation set Loss: 0.1893
#
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 3s 58us/sample - loss: 1.6044 - accuracy: 0.4816 - val_loss: 0.9249 - val_accuracy: 0.7690
# Epoch 2/10
# 50000/50000 [==============================] - 2s 48us/sample - loss: 0.6766 - accuracy: 0.8240 - val_loss: 0.5217 - val_accuracy: 0.8566
# Epoch 3/10
# 50000/50000 [==============================] - 2s 45us/sample - loss: 0.4739 - accuracy: 0.8687 - val_loss: 0.4174 - val_accuracy: 0.8816
# Epoch 4/10
# 50000/50000 [==============================] - 2s 46us/sample - loss: 0.4021 - accuracy: 0.8877 - val_loss: 0.3663 - val_accuracy: 0.8946
# Epoch 5/10
# 50000/50000 [==============================] - 2s 46us/sample - loss: 0.3618 - accuracy: 0.8984 - val_loss: 0.3352 - val_accuracy: 0.9027
# Epoch 6/10
# 50000/50000 [==============================] - 2s 49us/sample - loss: 0.3349 - accuracy: 0.9053 - val_loss: 0.3133 - val_accuracy: 0.9093
# Epoch 7/10
# 50000/50000 [==============================] - 2s 48us/sample - loss: 0.3156 - accuracy: 0.9107 - val_loss: 0.2961 - val_accuracy: 0.9151
# Epoch 8/10
# 50000/50000 [==============================] - 2s 47us/sample - loss: 0.3007 - accuracy: 0.9153 - val_loss: 0.2830 - val_accuracy: 0.9179
# Epoch 9/10
# 50000/50000 [==============================] - 2s 44us/sample - loss: 0.2885 - accuracy: 0.9186 - val_loss: 0.2727 - val_accuracy: 0.9209
# Epoch 10/10
# 50000/50000 [==============================] - 2s 47us/sample - loss: 0.2781 - accuracy: 0.9214 - val_loss: 0.2656 - val_accuracy: 0.9215
# Training set Accuracy:   0.92
# Training set Loss: 0.2733
#
# Validation set Accuracy:   0.92
# Validation set Loss: 0.2656

# %% [markdown]
# The two most important observations on these validation curves are:
#
#
# 1.   The model learning converges better
# 2.   The model learns slower
#
# Therefore, the number of epochs will be increased. The increased training time may result in a significant better model.
# The default learning rate of 0.001 will be tested as well to make a profound comparison.

# %%
epochs = 50
learning_rates = [0.001,0.0003,0.0001]
for lr in learning_rates:
  model = initial_model(lr=lr)
  model_history = model.fit(x_train, r_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val,r_val)
                    )
  analyse_result_plot(model,model_history)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 65us/sample - loss: 0.6298 - accuracy: 0.8097 - val_loss: 0.2713 - val_accuracy: 0.9198
# Epoch 2/50
# 50000/50000 [==============================] - 3s 56us/sample - loss: 0.2577 - accuracy: 0.9261 - val_loss: 0.2150 - val_accuracy: 0.9370
# Epoch 3/50
# 50000/50000 [==============================] - 3s 57us/sample - loss: 0
# 50000/50000 [==============================] - 3s 54us/sample - loss: 0.1807 - accuracy: 0.9481 - val_loss: 0.1898 - val_accuracy: 0.9444
# Epoch 33/50
# 50000/50000 [==============================] - 3s 57us/sample - loss: 0.1790 - accuracy: 0.9486 - val_loss: 0.1880 - val_accuracy: 0.9446
# Epoch 34/50
# 50000/50000 [==============================] - 3s 57us/sample - loss: 0.1771 - accuracy: 0.9494 - val_loss: 0.1871 - val_accuracy: 0.9448
# Epoch 35/50
# 50000/50000 [==============================] - 3s 57us/sample - loss: 0.1755 - accuracy: 0.9494 - val_loss: 0.1866 - val_accuracy: 0.9447
# Epoch 36/50
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.1740 - accuracy: 0.9499 - val_loss: 0.1844 - val_accuracy: 0.9455
# Epoch 37/50
# 50000/50000 [==============================] - 2s 49us/sample - loss: 0.1723 - accuracy: 0.9509 - val_loss: 0.1837 - val_accuracy: 0.9456
# Epoch 38/50
# 50000/50000 [==============================] - 2s 49us/sample - loss: 0.1707 - accuracy: 0.9516 - val_loss: 0.1837 - val_accuracy: 0.9453
# Epoch 39/50
# 50000/50000 [==============================] - 2s 48us/sample - loss: 0.1692 - accuracy: 0.9512 - val_loss: 0.1827 - val_accuracy: 0.9467
# Epoch 40/50
# 50000/50000 [==============================] - 2s 48us/sample - loss: 0.1680 - accuracy: 0.9520 - val_loss: 0.1833 - val_accuracy: 0.9464
# Epoch 41/50
# 50000/50000 [==============================] - 2s 50us/sample - loss: 0.1665 - accuracy: 0.9516 - val_loss: 0.1815 - val_accuracy: 0.9469
# Epoch 42/50
# 50000/50000 [==============================] - 2s 49us/sample - loss: 0.1652 - accuracy: 0.9526 - val_loss: 0.1806 - val_accuracy: 0.9467
# Epoch 43/50
# 50000/50000 [==============================] - 2s 50us/sample - loss: 0.1637 - accuracy: 0.9537 - val_loss: 0.1795 - val_accuracy: 0.9467
# Epoch 44/50
# 50000/50000 [==============================] - 2s 50us/sample - loss: 0.1629 - accuracy: 0.9532 - val_loss: 0.1790 - val_accuracy: 0.9469
# Epoch 45/50
# 50000/50000 [==============================] - 2s 49us/sample - loss: 0.1614 - accuracy: 0.9538 - val_loss: 0.1775 - val_accuracy: 0.9473
# Epoch 46/50
# 50000/50000 [==============================] - 2s 49us/sample - loss: 0.1602 - accuracy: 0.9540 - val_loss: 0.1779 - val_accuracy: 0.9479
# Epoch 47/50
# 50000/50000 [==============================] - 2s 50us/sample - loss: 0.1592 - accuracy: 0.9538 - val_loss: 0.1772 - val_accuracy: 0.9464
# Epoch 48/50
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.1580 - accuracy: 0.9542 - val_loss: 0.1767 - val_accuracy: 0.9469
# Epoch 49/50
# 50000/50000 [==============================] - 2s 49us/sample - loss: 0.1566 - accuracy: 0.9547 - val_loss: 0.1769 - val_accuracy: 0.9477
# Epoch 50/50
# 50000/50000 [==============================] - 2s 47us/sample - loss: 0.1557 - accuracy: 0.9553 - val_loss: 0.1749 - val_accuracy: 0.9485
# Training set Accuracy:   0.96
# Training set Loss: 0.1531
#
# Validation set Accuracy:   0.95
# Validation set Loss: 0.1749

# %% [markdown]
# There are still no significant improvements in validation loss.
# The validation curve is more smooth (less fluctuations) though, because the weight updates are more limited, so from now on we will keep the number of epochs fixed at 30 and the learning rate at 0.0003.
# There is still a small lack of generalisation, but the model is not completely overfitting to the training data.
# To improve both training and validation loss, the model will be made a little more complex by adding some extra fully connected layers and increasing the number of neurons in each layer. These fully connected layers are prone to overfitting, so dropout layers will be added as well.

# %%
epochs = 30
learning_rate = 0.0003

def improved_model(neurons=16,dropout_rate=0.01):
    model = Sequential()
    model.add(Dense(neurons, activation='relu', input_shape=(784,), kernel_initializer='he_uniform'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neurons, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(dropout_rate))
    # 2 extra fully connected layers
    model.add(Dense(neurons, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neurons, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(dropout_rate))

    model.add(Dense(num_classes, activation='softmax'))

    optimizer = tf.keras.optimizers.Adam(lr=learning_rate)
    model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy']) # save logloss AND accuracy
    return model

# %%
nb_neurons = [16,32]
for nb in nb_neurons:
  improved = improved_model(neurons=nb)
  # Fit to training data and analyze
  improved_history = improved.fit(x_train, r_train,
                                        batch_size=batch_size,
                                        epochs=epochs,
                                        verbose=1,
                                        validation_data=(x_val,r_val)
                                        )
  analyse_result_plot(improved,improved_history)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 4s 72us/sample - loss: 0.9899 - accuracy: 0.6858 - val_loss: 0.4610 - val_accuracy: 0.8693
# Epoch 2/30
# 50000/50000 [==============================] - 3s 57us/sample - loss: 0.4990 - accuracy: 0.8514 - val_loss: 0.3492 - val_accuracy: 0.9029
# Epoch 3/30
# 50000/50000 [==============================] - 3s 56us/sample - loss: 0.4124 - accuracy: 0.8771 - val_loss: 0.2985 - val_accuracy: 0.9162
# Epoch 4/30
# 50000/50000 [==============================] - 3s 55us/sample - loss: 0.3643 - accuracy: 0.8910 - val_loss: 0.2640 - val_accuracy: 0.9269
# Epoch 5/30
# 50000/50000 [==============================] - 3s 54us/sample - loss: 0.3359 - accuracy: 0.9008 - val_loss: 0.2470 - val_accuracy: 0.9293
# Epoch 6/30
# 50000/50000 [==============================] - 3s 56us/sample - loss: 0.3075 - accuracy: 0.9091 - val_loss: 0.2325 - val_accuracy: 0.9331
# Epoch 7/30
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.2879 - accuracy: 0.9147 - val_loss: 0.2224 - val_accuracy: 0.9345
# Epoch 8/30
# 50000/50000 [==============================] - 3s 56us/sample - loss: 0.2721 - accuracy: 0.9190 - val_loss: 0.2108 - val_accuracy: 0.9371
# Epoch 9/30
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.2627 - accuracy: 0.9216 - val_loss: 0.2128 - val_accuracy: 0.9370
# Epoch 10/30
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.2477 - accuracy: 0.9274 - val_loss: 0.2012 - val_accuracy: 0.9402
# Epoch 11/30
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.2406 - accuracy: 0.9284 - val_loss: 0.1978 - val_accuracy: 0.9412
# Epoch 12/30
# 50000/50000 [==============================] - 3s 54us/sample - loss: 0.2325 - accuracy: 0.9310 - val_loss: 0.1955 - val_accuracy: 0.9412
# Epoch 13/30
# 50000/50000 [==============================] - 3s 58us/sample - loss: 0.2245 - accuracy: 0.9335 - val_loss: 0.1918 - val_accuracy: 0.9433
# Epoch 14/30
# 50000/50000 [==============================] - 3s 55us/sample - loss: 0.2216 - accuracy: 0.9339 - val_loss: 0.1871 - val_accuracy: 0.9439
# Epoch 15/30
# 50000/50000 [==============================] - 3s 56us/sample - loss: 0.2176 - accuracy: 0.9351 - val_loss: 0.1840 - val_accuracy: 0.9453
# Epoch 16/30
# 50000/50000 [==============================] - 3s 57us/sample - loss: 0.2076 - accuracy: 0.9378 - val_loss: 0.1818 - val_accuracy: 0.9462
# Epoch 17/30
# 50000/50000 [==============================] - 3s 54us/sample - loss: 0.2078 - accuracy: 0.9369 - val_loss: 0.1811 - val_accuracy: 0.9455
# Epoch 18/30
# 50000/50000 [==============================] - 3s 57us/sample - loss: 0.2016 - accuracy: 0.9391 - val_loss: 0.1773 - val_accuracy: 0.9465
# Epoch 19/30
# 50000/50000 [==============================] - 3s 55us/sample - loss: 0.1976 - accuracy: 0.9405 - val_loss: 0.1781 - val_accuracy: 0.9465
# Epoch 20/30
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.1929 - accuracy: 0.9421 - val_loss: 0.1767 - val_accuracy: 0.9468
# Epoch 21/30
# 50000/50000 [==============================] - 3s 58us/sample - loss: 0.1931 - accuracy: 0.9422 - val_loss: 0.1783 - val_accuracy: 0.9460
# Epoch 22/30
# 50000/50000 [==============================] - 3s 57us/sample - loss: 0.1881 - accuracy: 0.9436 - val_loss: 0.1774 - val_accuracy: 0.9451
# Epoch 23/30
# 50000/50000 [==============================] - 3s 54us/sample - loss: 0
30
# 50000/50000 [==============================] - 3s 58us/sample - loss: 0.0840 - accuracy: 0.9735 - val_loss: 0.1208 - val_accuracy: 0.9636
# Epoch 21/30
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.0812 - accuracy: 0.9742 - val_loss: 0.1180 - val_accuracy: 0.9640
# Epoch 22/30
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.0788 - accuracy: 0.9751 - val_loss: 0.1161 - val_accuracy: 0.9650
# Epoch 23/30
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.0766 - accuracy: 0.9759 - val_loss: 0.1158 - val_accuracy: 0.9639
# Epoch 24/30
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.0722 - accuracy: 0.9778 - val_loss: 0.1128 - val_accuracy: 0.9667
# Epoch 25/30
# 50000/50000 [==============================] - 3s 63us/sample - loss: 0.0735 - accuracy: 0.9766 - val_loss: 0.1167 - val_accuracy: 0.9665
# Epoch 26/30
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.0707 - accuracy: 0.9775 - val_loss: 0.1167 - val_accuracy: 0.9656
# Epoch 27/30
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.0688 - accuracy: 0.9780 - val_loss: 0.1208 - val_accuracy: 0.9653
# Epoch 28/30
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.0657 - accuracy: 0.9787 - val_loss: 0.1137 - val_accuracy: 0.9666
# Epoch 29/30
# 50000/50000 [==============================] - 3s 58us/sample - loss: 0.0653 - accuracy: 0.9788 - val_loss: 0.1179 - val_accuracy: 0.9648
# Epoch 30/30
# 50000/50000 [==============================] - 3s 58us/sample - loss: 0.0636 - accuracy: 0.9798 - val_loss: 0.1185 - val_accuracy: 0.9682
# Training set Accuracy:   0.99
# Training set Loss: 0.0378
#
# Validation set Accuracy:   0.97
# Validation set Loss: 0.1185

# %% [markdown]
# The model is generalising very well for 16-width neuron layers, due to the dropout layers.
# For 32-width neuron layers, to model overfits to the training data. Increasing the dropout rate may result in better generalisation.

# %%
dropout_rates = [0.01,0.03,0.1,0.3]
nb = 32
for dr in dropout_rates:
  improved = improved_model(neurons=nb,dropout_rate=dr)
  # Fit to training data and analyze
  improved_history = improved.fit(x_train, r_train,
                                        batch_size=batch_size,
                                        epochs=epochs,
                                        verbose=1,
                                        validation_data=(x_val,r_val)
                                        )
  analyse_result_plot(improved,improved_history)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 4s 73us/sample - loss: 0.8270 - accuracy: 0.7434 - val_loss: 0.3009 - val_accuracy: 0.9154
# Epoch 2/30
# 50000/50000 [==============================] - 3s 63us/sample - loss: 0.3131 - accuracy: 0.9075 - val_loss: 0.2172 - val_accuracy: 0.9376
# Epoch 3/30
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.2446 - accuracy: 0.9274 - val_loss: 0.1832 - val_accuracy: 0.9467
# Epoch 4/30
# 50000/50000 [==============================] - 3s 58us/sample - loss: 0.2067 - accuracy: 0.9388 - val_loss: 0.1653 - val_accuracy: 0.9506
# Epoch 5/30
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.1846 - accuracy: 0.9439 - val_loss: 0.1503 - val_accuracy: 0.9549
# Epoch 6/30
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.1642 - accuracy: 0.9506 - val_loss: 0.1444 - val_accuracy: 0.9575
# Epoch 7/30
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.1508 - accuracy: 0.9540 - val_loss: 0.1336 - val_accuracy: 0.9598
# Epoch 8/30
# 50000/50000 [==============================] - 3s 62us/sample - loss: 0.1391 - accuracy: 0.9576 - val_loss: 0.1302 - val_accuracy: 0.9613
# Epoch 9/30
# 50000/50000 [==============================] - 3s 63us/sample - loss: 0.1305 - accuracy: 0.9602 - val_loss: 0.1286 - val_accuracy: 0.9625
# Epoch 10/30
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.1219 - accuracy: 0.9622 - val_loss: 0.1262 - val_accuracy: 0.9641
# Epoch 11/30
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.1155 - accuracy: 0.9655 - val_loss: 0.1234 - val_accuracy: 0.9622
# Epoch 12/30
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0
30
# 50000/50000 [==============================] - 3s 58us/sample - loss: 0.3416 - accuracy: 0.9023 - val_loss: 0.1953 - val_accuracy: 0.9408
# Epoch 5/30
# 50000/50000 [==============================] - 3s 62us/sample - loss: 0.3038 - accuracy: 0.9150 - val_loss: 0.1820 - val_accuracy: 0.9450
# Epoch 6/30
# 50000/50000 [==============================] - 3s 58us/sample - loss: 0.2832 - accuracy: 0.9208 - val_loss: 0.1725 - val_accuracy: 0.9470
# Epoch 7/30
# 50000/50000 [==============================] - 3s 58us/sample - loss: 0.2625 - accuracy: 0.9265 - val_loss: 0.1647 - val_accuracy: 0.9506
# Epoch 8/30
# 50000/50000 [==============================] - 3s 56us/sample - loss: 0.2494 - accuracy: 0.9296 - val_loss: 0.1607 - val_accuracy: 0.9526
# Epoch 9/30
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.2337 - accuracy: 0.9359 - val_loss: 0.1543 - val_accuracy: 0.9545
# Epoch 10/30
# 50000/50000 [==============================] - 3s 62us/sample - loss: 0.2241 - accuracy: 0.9366 - val_loss: 0.1511 - val_accuracy: 0.9550
# Epoch 11/30
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.2163 - accuracy: 0.9399 - val_loss: 0.1461 - val_accuracy: 0.9552
# Epoch 12/30
# 50000/50000 [==============================] - 3s 63us/sample - loss: 0.2068 - accuracy: 0.9422 - val_loss: 0.1409 - val_accuracy: 0.9577
# Epoch 13/30
# 50000/50000 [==============================] - 3s 58us/sample - loss: 0.1979 - accuracy: 0.9444 - val_loss: 0.1418 - val_accuracy: 0.9590
# Epoch 14/30
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.1912 - accuracy: 0.9459 - val_loss: 0.1405 - val_accuracy: 0.9580
# Epoch 15/30
# 50000/50000 [==============================] - 3s 57us/sample - loss: 0.1865 - accuracy: 0.9466 - val_loss: 0.1379 - val_accuracy: 0.9584
# Epoch 16/30
# 50000/50000 [==============================] - 3s 57us/sample - loss: 0.1795 - accuracy: 0.9482 - val_loss: 0.1385 - val_accuracy: 0.9586
# Epoch 17/30
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.1771 - accuracy: 0.9504 - val_loss: 0.1377 - val_accuracy: 0.9593
# Epoch 18/30
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.1744 - accuracy: 0.9501 - val_loss: 0.1402 - val_accuracy: 0.9595
# Epoch 19/30
# 50000/50000 [==============================] - 3s 64us/sample - loss: 0.1683 - accuracy: 0.9526 - val_loss: 0.1370 - val_accuracy: 0.9608
# Epoch 20/30
# 50000/50000 [==============================] - 3s 69us/sample - loss: 0.1659 - accuracy: 0.9532 - val_loss: 0.1332 - val_accuracy: 0.9612
# Epoch 21/30
#  1664/50000 [..............................] - ETA: 3s - loss: 0.1337 - accuracy: 0.9615
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-d1859bf02ccf> in <module>()
#       8                                         epochs=epochs,
#       9                                         verbose=1,
# ---> 10                                         validation_data=(x_val,r_val)
#      11                                         )
#      12   analyse_result_plot(improved,improved_history)
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/function.py in _build_call_outputs(self, result)
#    1927         j += 1
#    1928     ret = nest.pack_sequence_as(self._func_graph.structured_outputs,
# -> 1929                                 outputs_list, expand_composites=True)
#    1930     return ret
#    1931
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/util/nest.py in pack_sequence_as(structure, flat_sequence, expand_composites)
#     502     TypeError: `structure` is or contains a dict with non-sortable keys.
#     503   """
# --> 504   return _pack_sequence_as(structure, flat_sequence, expand_composites)
#     505
#     506
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/util/nest.py in _pack_sequence_as(structure, flat_sequence, expand_composites, sequence_fn)
#     456   try:
#     457     final_index, packed = _packed_nest_with_indices(structure, flat_sequence,
# --> 458                                                     0, is_seq, sequence_fn)
#     459     if final_index < len(flat_sequence):
#     460       raise IndexError
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/util/nest.py in _packed_nest_with_indices(structure, flat, index, is_seq, sequence_fn)
#     421       new_index, child = _packed_nest_with_indices(s, flat, index, is_seq,
#     422                                                    sequence_fn)
# --> 423       packed.append(sequence_fn(s, child))
#     424       index = new_index
#     425     else:
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/util/nest.py in _sequence_like(instance, args)
#     161     assert len(args) == 1
#     162     return instance._from_components(args[0])  # pylint: disable=protected-access
# --> 163   elif isinstance(instance, _six.moves.range):
#     164     return _sequence_like(list(instance), args)
#     165   elif isinstance(instance, _wrapt.ObjectProxy):
#
# KeyboardInterrupt:

# %% [markdown]
# Increasing the dropout rate did not help.
# The dropout rate will remain fixed at 0.01.
# The training and validation loss is still too high.
# There is still some bias and variance which can be decreased.
# If both statistics have to be improved, a valid solution could be to extract better features from the data. Since it is not yet allowed to use convolutional layers, looking at the misclassified samples where the model prediction is not sure might be inspirational.

# %%
dropout_rate = 0.01
improved = improved_model(neurons=nb,dropout_rate=dropout_rate)
improved.fit(x_train,r_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_val,r_val))

# Since the model will still be tweaked afterwards, it is analysed on the validation set instead of the test set
predictions = improved.predict(x_val)

# the predictions are class probabilities, 
# the argmax code line below finds the index of the class with the highest probability

val_predicted_class = np.argmax(predictions,axis=1)
misclassified = np.where(val_predicted_class!=r_val_class)[0]

# misclassified is a vector that contains the indices of all misclassified samples

print("There are ",misclassified.shape[0]," misclassified samples in the validation set.")

# %%
# this function plots the image with some annotations
def plot_image(predictions, true_label, img):
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions),
                                true_label),
                                color=color)


# this function shows the predictions for this sample
def plot_value_array(predictions, true_label):
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
# probabilities for class that will be predicted
maxprob = np.max(predictions, axis=1)

# find 20 less certain misclassified samples
less_certain = np.argsort(maxprob[misclassified])
less_certain = misclassified[less_certain[:20]]

# now we visualise the samples we found

# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 4
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  idx=less_certain[i]
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(predictions[idx], r_val_class[idx], np.reshape(x_val[idx],(28,28)))
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(predictions[idx], r_val_class[idx])
plt.tight_layout()
plt.show()

# %% [markdown]
# In some cases the prediction probability of the correct class is close to the prediction probability of the wrong class, in some cases it is not even close.
# Before applying some logic to change the prediction, the most uncertain predictions are plotted as well. Applying logic might change their prediction as well.

# %%
not_misclassified = np.where(val_predicted_class==r_val_class)[0]

# find 20 less certain misclassified samples
less_certain = np.argsort(maxprob[not_misclassified])
less_certain = not_misclassified[less_certain[:20]]

# now we visualise the samples we found

# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 4
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  idx=less_certain[i]
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(predictions[idx], r_val_class[idx], np.reshape(x_val[idx],(28,28)))
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(predictions[idx], r_val_class[idx])
plt.tight_layout()
plt.show()

# %% [markdown]
# As can be seen, it is quite risky to change the prediction when the model is uncertain, because the model is already correct sometimes.
